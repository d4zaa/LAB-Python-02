# %% [markdown]
# # Ejercicio 4 (1)

# %%
palabras = ["pinguino", "onda", "papaya", "oso", "casa", "reconocer", "python", "radar"]
numeros = [1, None, 25, 15, None, 3, 7, 9, 35]

palabras_largas = list(filter(lambda x: len(x) > 4, palabras))

no_nones = list(filter(lambda x: x != None, lista))

vocales = ('a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U')
inician_vocal = list(filter(lambda x: x.startswith(vocales), palabras))

palindromos = list(filter(lambda x: x == x[::-1], palabras))

terminan_en5 = list(filter(lambda n: str(n).endswith("5"), numeros))

productos = [
    {"nombre": "Teclado", "precio": 80},
    {"nombre": "Mouse", "precio": 40},
    {"nombre": "Monitor", "precio": 300},
    {"nombre": "Webcam", "precio": 150}
]
productos_mayor_a100 = list(filter(lambda p: p["precio"] > 100, productos))

# %%
#verificacion

print(palabras_largas)
print(no_nones)
print(inician_vocal)
print(palindromos)
print(terminan_en5)
# Out:
# ['pinguino', 'papaya', 'reconocer', 'python', 'radar']
# [1, 3, 7, 9, 35]
# ['onda', 'oso']
# ['oso', 'reconocer', 'radar']
# [25, 15, 35]
